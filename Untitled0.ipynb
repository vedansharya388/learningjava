# %% [markdown]
# <a href="https://colab.research.google.com/github/vedansharya388/learningjava/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=(input("enter your name"))
a=int(input("enter a number"))
b=int(input("enter a number"))
s=a+b
p=s/200*100
print(n)
print(p)
if p>=80 and p<=90:
 print("very good")
elif p>=60 and p<=70:
 print("nice result")
# Out:
# enter your namevedu
# enter a number78
# enter a number96
# vedu
# 87.0
# very good
